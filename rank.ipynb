# %%
import pandas as pd

# %%
df = pd.DataFrame({ 
    'name' : ['Tom','harry','bob','henry','harley'],
    'marks': [90,87,89,92,90]
})

# %%
df['student_rank'] = df['marks'].rank(method = 'average',ascending = False)

# %%
df
# Out:
#      name  marks  student_rank
# 0     Tom     90           2.5
# 1   harry     87           5.0
# 2     bob     89           4.0
# 3   henry     92           1.0
# 4  harley     90           2.5

# %%
df['student_rank'] = df['marks'].rank(method = 'max',ascending = False)

# %%
df
# Out:
#      name  marks  student_rank
# 0     Tom     90           3.0
# 1   harry     87           5.0
# 2     bob     89           4.0
# 3   henry     92           1.0
# 4  harley     90           3.0

# %%
df['student_rank'] = df['marks'].rank(method = 'min',ascending = False)

# %%
df
# Out:
#      name  marks  student_rank
# 0     Tom     90           2.0
# 1   harry     87           5.0
# 2     bob     89           4.0
# 3   henry     92           1.0
# 4  harley     90           2.0

# %%
df['student_rank'] = df['marks'].rank(method = 'first',ascending = False)

# %%
df
# Out:
#      name  marks  student_rank
# 0     Tom     90           2.0
# 1   harry     87           5.0
# 2     bob     89           4.0
# 3   henry     92           1.0
# 4  harley     90           3.0

# %%
df['student_rank'] = df['marks'].rank(method = 'dense',ascending = False)

# %%
df
# Out:
#      name  marks  student_rank
# 0     Tom     90           2.0
# 1   harry     87           4.0
# 2     bob     89           3.0
# 3   henry     92           1.0
# 4  harley     90           2.0

# %%
df["rank"] = df["marks"].rank(method="dense", ascending=False)
df[df["rank"] <= 3]
# Out:
#      name  marks  student_rank  rank
# 0     Tom     90           2.0   2.0
# 2     bob     89           3.0   3.0
# 3   henry     92           1.0   1.0
# 4  harley     90           2.0   2.0
