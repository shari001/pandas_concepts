# %%
import pandas as pd

# %%
df = pd.DataFrame({
    "name" : ["billy","Noah","mike","steve","mike"],
    "marks" : [87,72,71,66,71]
})

# %%
df
# Out:
#     name  marks
# 0  billy     87
# 1   Noah     72
# 2   mike     71
# 3  steve     66
# 4   mike     71

# %%
df.drop_duplicates(subset = ["name"], inplace = True)

# %%
df
# Out:
#     name  marks
# 0  billy     87
# 1   Noah     72
# 2   mike     71
# 3  steve     66

# %%
df.drop_duplicates(keep = 'last',inplace = True)

# %%
df
# Out:
#     name  marks
# 0  billy     87
# 1   Noah     72
# 3  steve     66
# 4   mike     71

# %%
df.drop_duplicates(keep = 'first')
# Out:
#     name  marks
# 0  billy     87
# 1   Noah     72
# 2   mike     71
# 3  steve     66
