# %%
import pandas as pd
df = pd.DataFrame({
    'Name' : ['bob','henry','casey','harry','jansen'],
     'department' : ['IT','IT','sales','IT','sales'],
    'salary' : [90000,89000,27000,49000,41000],
    'age'   :  [23,24,21,25,28],
    'height' : [159,167,178,172,167],
    'weight' : [76,71,67,69,70]
})

# %%
df.plot()
# Out:
# <Axes: >

# %%
df.plot(kind = 'barh')
# Out:
# <Axes: >

# %%
df["age"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
df['age'].plot(kind = 'hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
df.plot(
    kind="bar",
    title="monthly income",
    xlabel="EMP_ID",
    ylabel="saalry",
    figsize=(8,5),
    grid= True
)
# Out:
# <Axes: title={'center': 'monthly income'}, xlabel='EMP_ID', ylabel='saalry'>

# %%
#df.plot(kind = "scatter", x = "age", y = "Marks")
df.plot(kind="scatter", x="height", y="weight")
# Out:
# <Axes: xlabel='height', ylabel='weight'>

# %%
df.plot(kind = 'bar', grid = True)
plt.yscale('log')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 2
#       1 df.plot(kind = 'bar', grid = True)
# ----> 2 plt.yscale('log')
#
# NameError: name 'plt' is not defined

# %%
df.groupby('department')['salary'].mean().plot(kind = 'bar')
# Out:
# <Axes: xlabel='department'>
