# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'name': ['  Alice  ', 'bob', 'CHARLIE', 'david 123', 'eve', 'mike-smith'],
    'department': ['IT', 'sales', 'it', 'HR', 'Sales', 'hr']
})

# %%
df['name'].str.lower()
df['name'].str.upper()
df['name'].str.title()
# Out:
# 0       Alice
# 1           Bob
# 2       Charlie
# 3     David 123
# 4           Eve
# 5    Mike-Smith
# Name: name, dtype: object

# %%
df['name'].str.strip()
df['name'].str.lstrip()
df['name'].str.rstrip()
# Out:
# 0         Alice
# 1           bob
# 2       CHARLIE
# 3     david 123
# 4           eve
# 5    mike-smith
# Name: name, dtype: object

# %%
emp = pd.DataFrame({
    'name': [' Jonathan bylers ',' harry potter', 'mickle jackson '],
    'age': [23, 34, 21]
})

# %%
emp
# Out:
#                 name  age
# 0   Jonathan bylers    23
# 1       harry potter   34
# 2    mickle jackson    21

# %%
emp['name'].str.lstrip()
# Out:
# 0    Jonathan bylers
# 1        harry potter
# 2     mickle jackson
# Name: name, dtype: object

# %%
emp
# Out:
#                 name  age
# 0   Jonathan bylers    23
# 1       harry potter   34
# 2    mickle jackson    21

# %%
emp['name'].str.replace('harry','harry potter')
# Out:
# 0        Jonathan bylers
# 1     harry potter potter
# 2         mickle jackson
# Name: name, dtype: object

# %%
emp
# Out:
#                 name  age
# 0   Jonathan bylers    23
# 1       harry potter   34
# 2    mickle jackson    21

# %%
emp['name'].str.contains('h')
# Out:
# 0     True
# 1     True
# 2    False
# Name: name, dtype: bool

# %%
data_emp[data_emp['name'].str.startswith('m')]
# Out:
#       name  age
# 2  mickle    21

# %%
data_emp[data_emp['name'].str.endswith('y')]
# Out:
#     name  age
# 1  harry   34

# %%
emp['name'].str.len()
# Out:
# 0    17
# 1    13
# 2    15
# Name: name, dtype: int64

# %%
emp['name'].str.split('a', )
# Out:
# 0    [ Jon, th, n bylers ]
# 1         [ h, rry potter]
# 2       [mickle j, ckson ]
# Name: name, dtype: object

# %%
emp['name'].str.find('J')
# Out:
# 0    1
# 1   -1
# 2   -1
# Name: name, dtype: int64

# %%
emp['name'].str.get(2)
# Out:
# 0    o
# 1    a
# 2    c
# Name: name, dtype: object

# %%
emp['name'].str.slice(0, 8)
# Out:
# 0     Jonatha
# 1     harry p
# 2    mickle j
# Name: name, dtype: object
